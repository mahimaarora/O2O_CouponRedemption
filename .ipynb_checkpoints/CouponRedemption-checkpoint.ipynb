# %% [markdown]
# #### Background
# As smart phone penetration reaches the hundreds of millions mark, O2O (Online to Offline) requires businesses to have a strong presence both offline and online. APPs with O2O capabilities accumulate daily consumer behaviour and location data that require big data and commercial operations management. The competition at hand focuses on coupon redemption rates. Sending coupons is a general O2O marketing tool used to activate existing customers and attract new ones. While customers are happy to receive coupons that they want, they are frustrated when receiving coupons that they do not need. For merchants, sending unwanted coupons may erode brand equity and hinder marketing expense forecasting. Targeted marketing is an important technology to increase the coupon redemption rate, providing relevant discounts to customers and effective marketing tools to businesses. The competition provides participants with abundant O2O data in this field and expects contestants to predict whether the customer will use the coupon within a specified time frame.
# ### Data
# This competition provides real online and offline user consumption data from January 1, 2016 to June 30, 2016. The contestants are expected to predict the probability of customers redeeming a coupon within 15 days of receiving it.
# Note: To protect the privacy of users and merchants, data is desensitized and under biased sampling.
# ### Evaluation
# The results are evaluated based on the average AUC value. That is, the AUC value is calculated for every coupon_id. The average of each AUC value is the evaluation score. More information on AUC value calculation method on wikipedia.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_test=  pd.read_csv('ccf_offline_stage1_test_revised.csv')
print(df_test.shape)
df_test.head(20)
# Out:
# (113640, 6)
#     User_id  Merchant_id  Coupon_id Discount_rate  Distance  Date_received
# 0   4129537          450       9983          30:5       1.0       20160712
# 1   6949378         1300       3429          30:5       NaN       20160706
# 2   2166529         7113       6928        200:20       5.0       20160727
# 3   2166529         7113       1808        100:10       5.0       20160727
# 4   6172162         7605       6500          30:1       2.0       20160708
# 5   4005121          450       9983          30:5       0.0       20160706
# 6   4347394          450       9983          30:5       0.0       20160716
# 7   3094273          760      13602          30:5       1.0       20160727
# 8   5139970          450       9983          30:5      10.0       20160729
# 9   3237121          760      13602          30:5       1.0       20160703
# 10  6224386          450       9983          30:5       3.0       20160716
# 11  6488578          760      13602          30:5       0.0       20160712
# 12  4164865          450       9983          30:5       2.0       20160703
# 13  4164865         5138       8059         50:10       1.0       20160706
# 14  5468674          450       9983          30:5       NaN       20160713
# 15  6258178         7024       9144          10:1       0.0       20160706
# 16  3659521         6000       7341        150:30       6.0       20160727
# 17  3659521         2436      13181          20:1       3.0       20160717
# 18  3659521          760      13602          30:5       0.0       20160718
# 19  7333378          760      13602          30:5       0.0       20160704

# %%
df_test.isna().sum()
# Out:
# User_id              0
# Merchant_id          0
# Coupon_id            0
# Discount_rate        0
# Distance         12064
# Date_received        0
# dtype: int64

# %% [markdown]
# ### Training Offline Data

# %%
df_of = pd.read_csv('ccf_offline_stage1_train.csv')
print(df_of.shape)
df_of.head(10)
# Out:
# (1754884, 7)
#    User_id  Merchant_id  Coupon_id Discount_rate  Distance  Date_received  \
# 0  1439408         2632        NaN           NaN       0.0            NaN
# 1  1439408         4663    11002.0        150:20       1.0     20160528.0
# 2  1439408         2632     8591.0          20:1       0.0     20160217.0
# 3  1439408         2632     1078.0          20:1       0.0     20160319.0
# 4  1439408         2632     8591.0          20:1       0.0     20160613.0
# 5  1439408         2632        NaN           NaN       0.0            NaN
# 6  1439408         2632     8591.0          20:1       0.0     20160516.0
# 7  1832624         3381     7610.0        200:20       0.0     20160429.0
# 8  2029232         3381    11951.0        200:20       1.0     20160129.0
# 9  2029232          450     1532.0          30:5       0.0     20160530.0
#
#          Date
# 0  20160217.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5  20160516.0
# 6  20160613.0
# 7         NaN
# 8         NaN
# 9         NaN

# %%
df_of.isna().sum()
# Out:
# User_id               0
# Merchant_id           0
# Coupon_id        701602
# Discount_rate    701602
# Distance         106003
# Date_received    701602
# Date             977900
# dtype: int64

# %%
df_of['User_id'].value_counts().describe()
# Out:
# count    539438.000000
# mean          3.253171
# std           4.767551
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max         264.000000
# Name: User_id, dtype: float64

# %%
df_of[df_of["Date"].isna()].shape
# Out:
# (977900, 7)

# %%
df_of[(df_of["Date"].isna()) & (df_of["Coupon_id"].isna())].shape
# Out:
# (0, 7)

# %%
df_of.Coupon_id.describe()
# Out:
# count    1.053282e+06
# mean     6.815398e+03
# std      4.174276e+03
# min      1.000000e+00
# 25%      2.840000e+03
# 50%      7.430000e+03
# 75%      1.032300e+04
# max      1.404500e+04
# Name: Coupon_id, dtype: float64

# %%
df_of.Coupon_id.nunique()
# Out:
# 9738

# %%
df_of[df_of["Date"].isna()==False].shape
# Out:
# (776984, 7)

# %%
df_of[(df_of["Date"].isna()==False) & (df_of["Coupon_id"].isna())].shape
# Out:
# (701602, 7)

# %%
df_of[(df_of["Date"].isna()==False) & (df_of["Coupon_id"].isna()==False)].shape
# Out:
# (75382, 7)

# %% [markdown]
# ### Training Online Data

# %%
df_on = pd.read_csv('ccf_online_stage1_train.csv')
print(df_on.shape)
df_on_total = df_on.shape[0]
df_on.head()
# Out:
# (11429826, 7)
#     User_id  Merchant_id  Action  Coupon_id Discount_rate  Date_received  \
# 0  13740231        18907       2  100017492        500:50     20160513.0
# 1  13740231        34805       1        NaN           NaN            NaN
# 2  14336199        18907       0        NaN           NaN            NaN
# 3  14336199        18907       0        NaN           NaN            NaN
# 4  14336199        18907       0        NaN           NaN            NaN
#
#          Date
# 0         NaN
# 1  20160321.0
# 2  20160618.0
# 3  20160618.0
# 4  20160618.0

# %%
dfon.isna().sum()
# Out:
# User_id                 0
# Merchant_id             0
# Action                  0
# Coupon_id        10557469
# Discount_rate    10557469
# Date_received    10557469
# Date               655898
# dtype: int64

# %%
df_on[df_on["Date"].isna()].shape
# Out:
# (655898, 7)

# %%
#Date==Null and Coupon_id==Null: no such cases
df_on[(df_on["Date"].isna()) & (df_on["Coupon_id"].isna())].shape
# Out:
# (0, 7)

# %%
#Date==Null and Coupon_id!=Null: Coupon not redeemed(5.73%) and customer only 'gets Coupon'
df_not_redeemed = df_on[(df_on["Date"].isna()) & (df_on["Coupon_id"].isna()==False)]
df_not_redeemed.shape
# Out:
# (655898, 7)

# %%
df_not_redeemed["Action"].describe()
# Out:
# count    655898.0
# mean          2.0
# std           0.0
# min           2.0
# 25%           2.0
# 50%           2.0
# 75%           2.0
# max           2.0
# Name: Action, dtype: float64

# %%
df_on[df_on["Date"].isna()==False].shape
# Out:
# (10773928, 7)

# %%
#Date!=Null and Coupon_id==Null: No coupon(92.36%) and the customer only 'clicks' and 'buys'
df_no_coupon = df_on[(df_on["Date"].isna()==False) & (df_on["Coupon_id"].isna())]
df_no_coupon.shape
# Out:
# (10557469, 7)

# %%
df_no_coupon["Action"].unique()
# Out:
# array([1, 0])

# %%
#82.23% times customer only clicks
df_no_coupon[df_no_coupon["Action"]==0].shape
# Out:
# (9401780, 7)

# %%
#10.11% times customer buys with no coupon
df_no_coupon[df_no_coupon["Action"]==0]
# Out:
#            User_id  Merchant_id  Action Coupon_id Discount_rate  \
# 2         14336199        18907       0       NaN           NaN
# 3         14336199        18907       0       NaN           NaN
# 4         14336199        18907       0       NaN           NaN
# 5         14336199        18907       0       NaN           NaN
# 6         14336199        18907       0       NaN           NaN
# ...            ...          ...     ...       ...           ...
# 11429819  12985299        10813       0       NaN           NaN
# 11429820  13087731        52509       0       NaN           NaN
# 11429821  13087731        27715       0       NaN           NaN
# 11429822  13087731        52005       0       NaN           NaN
# 11429823  13087731        45611       0       NaN           NaN
#
#           Date_received        Date
# 2                   NaN  20160618.0
# 3                   NaN  20160618.0
# 4                   NaN  20160618.0
# 5                   NaN  20160618.0
# 6                   NaN  20160618.0
# ...                 ...         ...
# 11429819            NaN  20160414.0
# 11429820            NaN  20160609.0
# 11429821            NaN  20160629.0
# 11429822            NaN  20160324.0
# 11429823            NaN  20160422.0
#
# [9401780 rows x 7 columns]

# %%
df_on[(df_on["Date"].isna()==False) & (df_on["Coupon_id"].isna()==False)].shape
# Out:
# (216459, 7)

# %%
#coupon redeemed 1.89% times ('buys')
df_redeemed = df_on[(df_on["Date"].isna()==False) & (df_on["Coupon_id"].isna()==False)]
df_redeemed.shape
# Out:
# (216459, 7)

# %%
df_redeemed["Action"].unique()
# Out:
# array([1])

# %%
df_on.nunique(axis = 0)
# Out:
# User_id          762858
# Merchant_id        7999
# Action                3
# Coupon_id         27747
# Discount_rate        64
# Date_received       167
# Date                182
# dtype: int64

# %%
df_on.groupby(['User_id','Merchant_id']).head()
# Out:
#            User_id  Merchant_id  Action  Coupon_id Discount_rate  \
# Index
# 0         13740231        18907       2  100017492        500:50
# 1         13740231        34805       1        NaN           NaN
# 2         14336199        18907       0        NaN           NaN
# 3         14336199        18907       0        NaN           NaN
# 4         14336199        18907       0        NaN           NaN
# ...            ...          ...     ...        ...           ...
# 11429821  13087731        27715       0        NaN           NaN
# 11429822  13087731        52005       0        NaN           NaN
# 11429823  13087731        45611       0        NaN           NaN
# 11429824  13683699        18009       1        NaN           NaN
# 11429825  13683699        18009       1        NaN           NaN
#
#           Date_received        Date
# Index
# 0            20160513.0         NaN
# 1                   NaN  20160321.0
# 2                   NaN  20160618.0
# 3                   NaN  20160618.0
# 4                   NaN  20160618.0
# ...                 ...         ...
# 11429821            NaN  20160629.0
# 11429822            NaN  20160324.0
# 11429823            NaN  20160422.0
# 11429824            NaN  20160323.0
# 11429825            NaN  20160628.0
#
# [7555490 rows x 7 columns]

# %%
#When coupon==fixed, coupon redeemed the same day
df_fix = df_on[df_on["Coupon_id"]=="fixed"]
df_fix.shape, df_fix[df_fix["Date_received"]==df_fix["Date"]].shape
# Out:
# ((131546, 7), (131546, 7))

# %%
df_on.index.name="Index"

# %%
df_on[(df_on["User_id"]==14336199)]
# Out:
#         User_id  Merchant_id  Action Coupon_id Discount_rate  Date_received  \
# Index
# 2      14336199        18907       0       NaN           NaN            NaN
# 3      14336199        18907       0       NaN           NaN            NaN
# 4      14336199        18907       0       NaN           NaN            NaN
# 5      14336199        18907       0       NaN           NaN            NaN
# 6      14336199        18907       0       NaN           NaN            NaN
# 7      14336199        18907       0       NaN           NaN            NaN
# 8      14336199        18907       0       NaN           NaN            NaN
# 9      14336199        18907       0       NaN           NaN            NaN
# 10     14336199        38810       0       NaN           NaN            NaN
# 11     14336199        38810       0       NaN           NaN            NaN
# 12     14336199        38810       0       NaN           NaN            NaN
# 13     14336199        38810       0       NaN           NaN            NaN
# 14     14336199        18907       0       NaN           NaN            NaN
# 15     14336199        18907       0       NaN           NaN            NaN
# 16     14336199        37005       0       NaN           NaN            NaN
# 17     14336199        14305       0       NaN           NaN            NaN
# 18     14336199        18907       0       NaN           NaN            NaN
#
#              Date
# Index
# 2      20160618.0
# 3      20160618.0
# 4      20160618.0
# 5      20160618.0
# 6      20160618.0
# 7      20160618.0
# 8      20160618.0
# 9      20160618.0
# 10     20160126.0
# 11     20160126.0
# 12     20160126.0
# 13     20160126.0
# 14     20160127.0
# 15     20160127.0
# 16     20160412.0
# 17     20160127.0
# 18     20160618.0

# %%
df_on[(df_on["User_id"]==10998966) & (df_on["Merchant_id"]==14305)]
# Out:
#           User_id  Merchant_id  Action  Coupon_id Discount_rate  \
# Index
# 8451625  10998966        14305       2  100020104        500:50
# 8451626  10998966        14305       2  100020104        500:50
# 8451627  10998966        14305       0        NaN           NaN
# 8451628  10998966        14305       0        NaN           NaN
# 8451629  10998966        14305       0        NaN           NaN
# ...           ...          ...     ...        ...           ...
# 8453528  10998966        14305       2  100043310       300:100
# 8453529  10998966        14305       1        NaN           NaN
# 8453530  10998966        14305       1        NaN           NaN
# 8453531  10998966        14305       1        NaN           NaN
# 8453535  10998966        14305       2  100020104        500:50
#
#          Date_received        Date
# Index
# 8451625     20160218.0         NaN
# 8451626     20160218.0         NaN
# 8451627            NaN  20160218.0
# 8451628            NaN  20160218.0
# 8451629            NaN  20160218.0
# ...                ...         ...
# 8453528     20160505.0         NaN
# 8453529            NaN  20160104.0
# 8453530            NaN  20160104.0
# 8453531            NaN  20160104.0
# 8453535     20160218.0         NaN
#
# [1851 rows x 7 columns]

# %%
df_on.columns
# Out:
# Index(['User_id', 'Merchant_id', 'Action', 'Coupon_id', 'Discount_rate',
#        'Date_received', 'Date'],
#       dtype='object')

# %%
df_on.drop_duplicates().shape
# Out:
# (5822543, 7)

# %%
x = 'g8h.|$hTdo+jC9^@'    
df_on_unique = (df_on.fillna(x).groupby(['User_id', 'Merchant_id', 'Action', 'Coupon_id', 'Discount_rate',
       'Date_received', 'Date']).size().reset_index()
               .rename(columns={0 : 'Count'}).replace(x,np.NaN))
df_on_unique
# Out:
#           User_id  Merchant_id  Action  Coupon_id Discount_rate  \
# 0               4        25104       2  100145044        100:10
# 1               4        45612       1        NaN           NaN
# 2              36        46701       0        NaN           NaN
# 3              64        11200       0        NaN           NaN
# 4              64        29214       0        NaN           NaN
# ...           ...          ...     ...        ...           ...
# 5822538  15499999        55202       0        NaN           NaN
# 5822539  15499999        56502       0        NaN           NaN
# 5822540  15499999        59011       0        NaN           NaN
# 5822541  15499999        59512       0        NaN           NaN
# 5822542  15500000        25913       0        NaN           NaN
#
#          Date_received        Date  Count
# 0           20160331.0         NaN      1
# 1                  NaN  20160308.0      1
# 2                  NaN  20160120.0      1
# 3                  NaN  20160526.0      1
# 4                  NaN  20160606.0      1
# ...                ...         ...    ...
# 5822538            NaN  20160317.0      8
# 5822539            NaN  20160227.0      1
# 5822540            NaN  20160321.0      1
# 5822541            NaN  20160116.0      1
# 5822542            NaN  20160519.0      1
#
# [5822543 rows x 8 columns]

# %%
df_on_unique.Count.describe()
# Out:
# count    5.822543e+06
# mean     1.963030e+00
# std      3.430659e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      6.300000e+02
# Name: Count, dtype: float64

# %%
arr = list(df_on_unique["Count"])
arr.sort(reverse=True)
arr
# Out:
# [630,
#  504,
#  444,
#  432,
#  378,
#  367,
#  336,
#  336,
#  333,
#  322,
#  320,
#  318,
#  316,
#  316,
#  310,
#  306,
#  295,
#  293,
#  282,
#  281,
#  280,
#  278,
#  265,
#  264,
#  262,
#  258,
#  257,
#  256,
#  255,
#  252,
#  245,
#  240,
#  236,
#  232,
#  232,
#  232,
#  231,
#  231,
#  231,
#  229,
#  229,
#  228,
#  226,
#  224,
#  222,
#  222,
#  222,
#  217,
#  215,
#  213,
#  212,
#  210,
#  210,
#  210,
#  210,
#  209,
#  209,
#  208,
#  206,
#  206,
#  206,
#  202,
#  202,
#  202,
#  198,
#  198,
#  196,
#  196,
#  195,
#  195,
#  195,
#  195,
#  195,
#  192,
#  192,
#  192,
#  192,
#  191,
#  190,
#  188,
#  188,
#  187,
#  186,
#  186,
#  186,
#  186,
#  184,
#  184,
#  184,
#  183,
#  183,
#  182,
#  178,
#  178,
#  178,
#  177,
#  177,
#  177,
#  176,
#  176,
#  176,
#  176,
#  175,
#  175,
#  175,
#  175,
#  173,
#  173,
#  172,
#  172,
#  171,
#  171,
#  170,
#  170,
#  170,
#  170,
#  170,
#  169,
#  169,
#  169,
#  169,
#  168,
#  168,
#  166,
#  165,
#  164,
#  164,
#  162,
#  162,
#  161,
#  160,
#  160,
#  160,
#  159,
#  159,
#  159,
#  159,
#  158,
#  158,
#  158,
#  157,
#  157,
#  155,
#  155,
#  155,
#  155,
#  155,
#  154,
#  154,
#  154,
#  153,
#  153,
#  153,
#  153,
#  152,
#  152,
#  152,
#  152,
#  152,
#  152,
#  152,
#  152,
#  152,
#  151,
#  151,
#  151,
#  151,
#  150,
#  150,
#  150,
#  149,
#  149,
#  148,
#  148,
#  148,
#  148,
#  147,
#  147,
#  147,
#  147,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  146,
#  145,
#  145,
#  145,
#  145,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  143,
#  143,
#  143,
#  143,
#  143,
#  142,
#  142,
#  142,
#  142,
#  141,
#  141,
#  141,
#  141,
#  140,
#  140,
#  140,
#  140,
#  139,
#  139,
#  139,
#  139,
#  138,
#  138,
#  138,
#  138,
#  138,
#  138,
#  138,
#  138,
#  137,
#  137,
#  137,
#  137,
#  137,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  135,
#  135,
#  135,
#  134,
#  134,
#  134,
#  134,
#  133,
#  133,
#  133,
#  132,
#  132,
#  132,
#  132,
#  132,
#  132,
#  132,
#  132,
#  131,
#  131,
#  131,
#  131,
#  130,
#  130,
#  130,
#  129,
#  129,
#  129,
#  129,
#  129,
#  129,
#  129,
#  129,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  127,
#  127,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  125,
#  125,
#  125,
#  125,
#  125,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  121,
#  121,
#  121,
#  121,
#  121,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  119,
#  119,
#  119,
#  119,
#  119,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  109,
#  109,
#  109,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  96,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  ...]

# %%
df_on_unique["Count"].hist(bins=5)

# %%
df_on_unique[df_on_unique["User_id"]==288360]
# Out:
#        User_id  Merchant_id  Action  Coupon_id Discount_rate  Date_received  \
# 52844   288360        14305       0        NaN           NaN            NaN
# 52845   288360        14305       0        NaN           NaN            NaN
# 52846   288360        14305       0        NaN           NaN            NaN
# 52847   288360        14305       0        NaN           NaN            NaN
# 52848   288360        14305       1        NaN           NaN            NaN
# 52849   288360        14305       2  100142702        100:10     20160615.0
# 52850   288360        14305       2  100179873        300:50     20160615.0
# 52851   288360        19505       0        NaN           NaN            NaN
# 52852   288360        19710       0        NaN           NaN            NaN
# 52853   288360        19710       0        NaN           NaN            NaN
# 52854   288360        19710       0        NaN           NaN            NaN
# 52855   288360        27715       0        NaN           NaN            NaN
# 52856   288360        27715       0        NaN           NaN            NaN
# 52857   288360        30610       0        NaN           NaN            NaN
# 52858   288360        31303       0        NaN           NaN            NaN
# 52859   288360        36705       0        NaN           NaN            NaN
# 52860   288360        38310       2  100009374          50:5     20160128.0
# 52861   288360        38310       2  100101136          30:1     20160128.0
# 52862   288360        43506       0        NaN           NaN            NaN
# 52863   288360        43802       0        NaN           NaN            NaN
# 52864   288360        43802       0        NaN           NaN            NaN
# 52865   288360        43802       1  100229756          50:5     20160112.0
# 52866   288360        43802       1      fixed         fixed     20160112.0
# 52867   288360        43802       1      fixed         fixed     20160118.0
# 52868   288360        45308       0        NaN           NaN            NaN
# 52869   288360        49405       0        NaN           NaN            NaN
# 52870   288360        50301       0        NaN           NaN            NaN
# 52871   288360        50502       0        NaN           NaN            NaN
# 52872   288360        56401       0        NaN           NaN            NaN
#
#              Date  Count
# 52844  20160615.0     14
# 52845  20160616.0    322
# 52846  20160617.0    166
# 52847  20160618.0    139
# 52848  20160618.0      7
# 52849         NaN      1
# 52850         NaN      1
# 52851  20160514.0      5
# 52852  20160410.0     11
# 52853  20160514.0     18
# 52854  20160521.0      1
# 52855  20160410.0      2
# 52856  20160414.0      1
# 52857  20160104.0      2
# 52858  20160206.0      1
# 52859  20160514.0      1
# 52860         NaN      1
# 52861         NaN      1
